# %% [markdown]
# ## Pandas Complete tutorial for data science in 2026

# %%
# importing libraries
import numpy as np
import pandas as pd

# %% [markdown]
# ## 2.Loading Different Data Formats Into a Pandas Data Frame

# %%
# Import Dataset
df=pd.read_csv("C:\\pandas\\dataset\\online_store_customer_data.csv")

# %%
df
# Out:
#      Transaction_date  Transaction_ID  Gender   Age Marital_status  \
# 0            1/1/2019          151200  Female  19.0         Single
# 1            1/1/2019          151201    Male  49.0         Single
# 2            1/1/2019          151202    Male  63.0        Married
# 3            1/1/2019          151203     NaN  18.0         Single
# 4            1/1/2019          151204    Male  27.0         Single
# ...               ...             ...     ...   ...            ...
# 2507         5/1/2021          153695  Female  57.0         Single
# 2508         5/1/2021          153696  Female  36.0        Married
# 2509         5/1/2021          153697    Male  22.0         Single
# 2510         5/1/2021          153698     NaN  44.0         Single
# 2511         5/1/2021          153699    Male  48.0         Single
#
#          State_names   Segment Employees_status Payment_method  Referal  \
# 0             Kansas     Basic     Unemployment          Other      1.0
# ...

# %%
df.head()
# Out:
#   Transaction_date  Transaction_ID  Gender   Age Marital_status  State_names  \
# 0         1/1/2019          151200  Female  19.0         Single       Kansas
# 1         1/1/2019          151201    Male  49.0         Single     Illinois
# 2         1/1/2019          151202    Male  63.0        Married   New Mexico
# 3         1/1/2019          151203     NaN  18.0         Single     Virginia
# 4         1/1/2019          151204    Male  27.0         Single  Connecticut
#
#     Segment Employees_status Payment_method  Referal  Amount_spent
# 0     Basic     Unemployment          Other      1.0       2051.36
# 1     Basic    self-employed           Card      0.0        544.04
# 2     Basic          workers         PayPal      1.0       1572.60
# 3  Platinum          workers           Card      NaN       1199.79
# 4     Basic    self-employed           Card      0.0           NaN

# %%
df.tail(7)
# Out:
#      Transaction_date  Transaction_ID  Gender   Age Marital_status  \
# 2505        4/30/2021          153693    Male  54.0        Married
# 2506        4/30/2021          153694    Male  34.0         Single
# 2507         5/1/2021          153695  Female  57.0         Single
# 2508         5/1/2021          153696  Female  36.0        Married
# 2509         5/1/2021          153697    Male  22.0         Single
# 2510         5/1/2021          153698     NaN  44.0         Single
# 2511         5/1/2021          153699    Male  48.0         Single
#
#          State_names   Segment Employees_status Payment_method  Referal  \
# 2505         Alabama     Basic        Employees           Card      0.0
# 2506         Florida   Missing        Employees          Other      1.0
# 2507  South Carolina  Platinum    self-employed           Card      0.0
# 2508          Hawaii    Silver    self-employed         PayPal      1.0
# ...

# %%
df.shape
# Out:
# (2512, 11)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2512 entries, 0 to 2511
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Transaction_date  2512 non-null   object
#  1   Transaction_ID    2512 non-null   int64
#  2   Gender            2484 non-null   object
#  3   Age               2470 non-null   float64
#  4   Marital_status    2512 non-null   object
#  5   State_names       2512 non-null   object
#  6   Segment           2512 non-null   object
#  7   Employees_status  2486 non-null   object
#  8   Payment_method    2512 non-null   object
#  9   Referal           2356 non-null   float64
#  10  Amount_spent      2270 non-null   float64
# dtypes: float64(3), int64(1), object(7)
# memory usage: 216.0+ KB

# %%
# loading csv file with first 2 rows without header
df = pd.read_csv('C:\\pandas\\dataset\\online_store_customer_data.csv',skiprows=2)

# %%
# Loading csv file with skip first 2 rows without header
df_csv = pd.read_csv('C:\\pandas\\dataset\\online_store_customer_data.csv',skiprows=3)
df_csv.head()
# Out:
#    1/1/2019  151202    Male    63  Married   New Mexico     Basic  \
# 0  1/1/2019  151203     NaN  18.0   Single     Virginia  Platinum
# 1  1/1/2019  151204    Male  27.0   Single  Connecticut     Basic
# 2  1/3/2019  151205    Male  71.0   Single       Hawaii     Basic
# 3  1/3/2019  151206  Female  34.0  Married   New Mexico  Platinum
# 4  1/3/2019  151207    Male  37.0  Married  Connecticut     Basic
#
#          workers  PayPal    1   1572.6
# 0        workers    Card  NaN  1199.79
# 1  self-employed    Card  0.0      NaN
# 2      Employees  PayPal  1.0  2922.66
# 3      Employees  PayPal  1.0  1481.42
# 4        workers  PayPal  1.0  1149.55

# %% [markdown]
# ## Read CSV file from URL

# %%
# Read CSV file from URL
url1="https://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data"
df_url = pd.read_csv(url1)
df_url
# Out:
#      5.1  3.5  1.4  0.2     Iris-setosa
# 0    4.9  3.0  1.4  0.2     Iris-setosa
# 1    4.7  3.2  1.3  0.2     Iris-setosa
# 2    4.6  3.1  1.5  0.2     Iris-setosa
# 3    5.0  3.6  1.4  0.2     Iris-setosa
# 4    5.4  3.9  1.7  0.4     Iris-setosa
# ..   ...  ...  ...  ...             ...
# 144  6.7  3.0  5.2  2.3  Iris-virginica
# 145  6.3  2.5  5.0  1.9  Iris-virginica
# 146  6.5  3.0  5.2  2.0  Iris-virginica
# 147  6.2  3.4  5.4  2.3  Iris-virginica
# 148  5.9  3.0  5.1  1.8  Iris-virginica
#
# [149 rows x 5 columns]

# %%
pip install ucimlrepo
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# import the dataset 
from ucimlrepo import fetch_ucirepo 
  
# fetch dataset 
car_evaluation = fetch_ucirepo(id=19) 
  
# data (as pandas dataframes) 
X = car_evaluation.data.features 
y = car_evaluation.data.targets 
  
# metadata 
print(car_evaluation.metadata) 
  
# variable information 
print(car_evaluation.variables)
# Out:
# {'uci_id': 19, 'name': 'Car Evaluation', 'repository_url': 'https://archive.ics.uci.edu/dataset/19/car+evaluation', 'data_url': 'https://archive.ics.uci.edu/static/public/19/data.csv', 'abstract': 'Derived from simple hierarchical decision model, this database may be useful for testing constructive induction and structure discovery methods.', 'area': 'Other', 'tasks': ['Classification'], 'characteristics': ['Multivariate'], 'num_instances': 1728, 'num_features': 6, 'feature_types': ['Categorical'], 'demographics': [], 'target_col': ['class'], 'index_col': None, 'has_missing_values': 'no', 'missing_values_symbol': None, 'year_of_dataset_creation': 1988, 'last_updated': 'Thu Aug 10 2023', 'dataset_doi': '10.24432/C5JP48', 'creators': ['Marko Bohanec'], 'intro_paper': {'ID': 249, 'type': 'NATIVE', 'title': 'Knowledge acquisition and explanation for multi-attribute decision making', 'authors': 'M. Bohanec, V. Rajkovič', 'venue': '8th Intl Workshop on Expert Systems and their Applications
# ...

# %% [markdown]
# # Write CSV file

# %% [markdown]
# # Read text file

# %%
# read plain text file 
df_txt = pd.read_csv("C:\\pandas\\dataset\\demo_text.txt")
df_txt
# Out:
#    Hello
# 0       1
# 1       2
# 2       3

# %% [markdown]
# # read Excel file

# %%
# read excel file
df_excel = pd.read_excel('C:\\pandas\\dataset\\excel_file.xlsx',sheet_name='Data')
df_excel
# Out:
#   Transaction_date  Transaction_ID  Gender  Age Marital_status   State_names  \
# 0        3/10/2019          151378  Female   25         Single       Wyoming
# 1         7/2/2019          151751  Female   42         Single      Delaware
# 2        6/14/2019          151689    Male   38        Married       Montana
# 3         8/5/2019          151849    Male   24        Married  Rhode Island
#
#     Segment Employees_status Payment_method  Referal  Amount_spent  \
# 0  Platinum     Unemployment           Card        1       2740.57
# 1     Basic     Unemployment           Card        0        977.80
# 2     Basic          workers         PayPal        1       2978.21
# 3     Basic          workers           Card        1       1157.79
#
#    Transaction_ID.1
# 0            151378
# 1            151751
# 2            151689
# 3            151849

# %%
# save dataframe to the excel file
df_url.to_csv('demo.xlsx')

# %% [markdown]
# # 3.1 data exploring

# %% [markdown]
# # Retrieving sample rows from data frame

# %%
# display random 7 sample rows
df.sample(7)
# Out:
#         1/1/2019  151201    Male    49   Single       Illinois     Basic  \
# 1533   5/30/2020  152723  Female  54.0   Single       Illinois     Basic
# 1339   3/17/2020  152529    Male  43.0   Single     New Mexico  Platinum
# 1302    3/2/2020  152492    Male  26.0  Married       Maryland    Silver
# 2205   1/20/2021  153395  Female  59.0  Married      Minnesota   Missing
# 2044  11/22/2020  153234  Female  26.0  Married  New Hampshire     Basic
# 1210   1/30/2020  152400  Female  76.0  Married         Alaska     Basic
# 253    3/31/2019  151443  Female  76.0   Single        Vermont  Platinum
#
#       self-employed    Card    0   544.04
# 1533        workers    Card  1.0  1762.21
# 1339  self-employed  PayPal  1.0   828.36
# 1302      Employees  PayPal  1.0     8.67
# 2205      Employees  PayPal  1.0  2767.44
# 2044        workers   Other  0.0  2417.10
# 1210      Employees  PayPal  0.0  1207.82
# 253       Employees   Other  1.0  1672.01

# %% [markdown]
# # Retrieving information about dataframe

# %%
# display datatypes
df.dtypes
# Out:
# 1/1/2019          object
# 151201             int64
# Male              object
# 49               float64
# Single            object
# Illinois          object
# Basic             object
# self-employed     object
# Card              object
# 0                float64
# 544.04           float64
# dtype: object

# %%
df.dtypes.value_counts()
# Out:
# object     7
# float64    3
# int64      1
# Name: count, dtype: int64

# %% [markdown]
# # Display numbers of rows and columns.

# %%
df.columns
# Out:
# Index(['1/1/2019', '151201', 'Male', '49', 'Single', 'Illinois', 'Basic',
#        'self-employed', 'Card', '0', '544.04'],
#       dtype='object')

# %%
#display Age columns first 6 rows data
df_excel['Age'].head(6)
# Out:
# 0    25
# 1    42
# 2    38
# 3    24
# Name: Age, dtype: int64

# %% [markdown]
# # 3.2 Data clianing

# %% [markdown]
# ## Delete Columns name

# %%
# Dropunwanted columns
df_excel.drop(['Transaction_ID'],axis=1,inplace=True)

# %% [markdown]
# # Change the columns name

# %%
df_excel
# Out:
#   Transaction_date  Gender  Age Marital_status   State_names   Segment  \
# 0        3/10/2019  Female   25         Single       Wyoming  Platinum
# 1         7/2/2019  Female   42         Single      Delaware     Basic
# 2        6/14/2019    Male   38        Married       Montana     Basic
# 3         8/5/2019    Male   24        Married  Rhode Island     Basic
#
#   Employees_status Payment_method  Referal  Amount_spent  Transaction_ID.1
# 0     Unemployment           Card        1       2740.57            151378
# 1     Unemployment           Card        0        977.80            151751
# 2          workers         PayPal        1       2978.21            151689
# 3          workers           Card        1       1157.79            151849

# %%
df_col = pd.read_csv('C:\\pandas\\dataset\\online_store_customer_data.csv')

# %% [markdown]
# # Adding a new column to a DataFrame

# %%
# add a new ajusted column whith value will be amount_spent + 10
df_col['Test'] = df_col['Amount_spent'] * 10

# %%
df_col.head(3)
# Out:
#   Transaction_date  Transaction_ID  Gender   Age Marital_status State_names  \
# 0         1/1/2019          151200  Female  19.0         Single      Kansas
# 1         1/1/2019          151201    Male  49.0         Single    Illinois
# 2         1/1/2019          151202    Male  63.0        Married  New Mexico
#
#   Segment Employees_status Payment_method  Referal  Amount_spent     Test
# 0   Basic     Unemployment          Other      1.0       2051.36  20513.6
# 1   Basic    self-employed           Card      0.0        544.04   5440.4
# 2   Basic          workers         PayPal      1.0       1572.60  15726.0

# %%
# changing female to woman and woman to male
df_col.loc[df_col['Gender'] == 'Female', 'Gender'] = 'Woman'
df_col.loc[df_col['Gender'] == 'Male', 'Gender'] = 'Man'

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2510 entries, 0 to 2509
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   1/1/2019       2510 non-null   object
#  1   151201         2510 non-null   int64
#  2   Male           2482 non-null   object
#  3   49             2468 non-null   float64
#  4   Single         2510 non-null   object
#  5   Illinois       2510 non-null   object
#  6   Basic          2510 non-null   object
#  7   self-employed  2484 non-null   object
#  8   Card           2510 non-null   object
#  9   0              2354 non-null   float64
#  10  544.04         2268 non-null   float64
# dtypes: float64(3), int64(1), object(7)
# memory usage: 215.8+ KB

# %%
df_col.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2512 entries, 0 to 2511
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Transaction_date  2512 non-null   object
#  1   Transaction_ID    2512 non-null   int64
#  2   Gender            2484 non-null   object
#  3   Age               2470 non-null   float64
#  4   Marital_status    2512 non-null   object
#  5   State_names       2512 non-null   object
#  6   Segment           2512 non-null   object
#  7   Employees_status  2486 non-null   object
#  8   Payment_method    2512 non-null   object
#  9   Referal           2356 non-null   float64
#  10  Amount_spent      2270 non-null   float64
#  11  Test              2270 non-null   float64
# dtypes: float64(4), int64(1), object(7)
# memory usage: 235.6+ KB

# %%
# change object type to datefime64 format
df_col['Transaction_date'] = df_col['Transaction_date'].astype('datetime64[ns]')

# change float64 to float32 of Referal columns
df_col['Referal'] = df_col['Referal'].astype('float32')

# %%
print(df_col.columns.tolist())
# Out:
# ['Transaction_date', 'Transaction_ID', 'Gender', 'Age', 'Marital_status', 'State_names', 'Segment', 'Employees_status', 'Payment_method', 'Referal', 'Amount_spent', 'Test']

# %%
df_col.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2512 entries, 0 to 2511
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Transaction_date  2512 non-null   datetime64[ns]
#  1   Transaction_ID    2512 non-null   int64
#  2   Gender            2484 non-null   object
#  3   Age               2470 non-null   float64
#  4   Marital_status    2512 non-null   object
#  5   State_names       2512 non-null   object
#  6   Segment           2512 non-null   object
#  7   Employees_status  2486 non-null   object
#  8   Payment_method    2512 non-null   object
#  9   Referal           2356 non-null   float32
#  10  Amount_spent      2270 non-null   float64
#  11  Test              2270 non-null   float64
# dtypes: datetime64[ns](1), float32(1), float64(3), int64(1), object(6)
# memory usage: 225.8+ KB

# %%
print(df_col.columns)
# Out:
# Index(['Transaction_date', 'Transaction_ID', 'Gender', 'Age', 'Marital_status',
#        'State_names', 'Segment', 'Employees_status', 'Payment_method',
#        'Referal', 'Amount_spent', 'Test'],
#       dtype='object')

# %%
print(df_col['Gender'])
# Out:
# 0       Woman
# 1         Man
# 2         Man
# 3         NaN
# 4         Man
#         ...
# 2507    Woman
# 2508    Woman
# 2509      Man
# 2510      NaN
# 2511      Man
# Name: Gender, Length: 2512, dtype: object

# %% [markdown]
# # 3.3 Remove dublicate

# %%
# display dublicated 
df_col.duplicated().sum()
# Out:
# np.int64(12)

# %%
# display dublicated 
df_col.duplicated().head()
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# dtype: bool

# %%
# duplicated rows display, keep arguments will--- 'first','last' 
duplicate_value = df.duplicated(keep='first')
duplicate_value
df.loc[duplicate_value,:]
# Out:
#       1/1/2019  151201    Male    49   Single        Illinois     Basic  \
# 62   1/25/2019  151259    Male  73.0  Married   West Virginia     Basic
# 63   1/26/2019  151260    Male  55.0  Married          Kansas     Basic
# 64   1/26/2019  151261  Female  72.0  Married            Iowa    Silver
# 65   1/26/2019  151262    Male  15.0  Married  South Carolina     Basic
# 66   1/27/2019  151263  Female  63.0   Single           Texas      Gold
# 107   2/6/2019  151297    Male  60.0  Married            Utah    Silver
# 108   2/7/2019  151298  Female  45.0  Married        Missouri  Platinum
# 109   2/8/2019  151299    Male  33.0   Single         Arizona    Silver
# 110   2/8/2019  151300    Male  24.0  Married  South Carolina     Basic
# 111   2/8/2019  151301  Female  53.0   Single        Colorado     Basic
# 112   2/8/2019  151302  Female  70.0  Married   New Hampshire   Missing
# 113   2/8/2019  151303    Male  16.0  Married        Nebraska     Basic
#
# ...

# %%
# dropping all duplicate values
df.drop_duplicates(keep = 'first' , inplace = True)
df.drop_duplicates()
# Out:
#       1/1/2019  151201    Male    49   Single        Illinois     Basic  \
# 0     1/1/2019  151202    Male  63.0  Married      New Mexico     Basic
# 1     1/1/2019  151203     NaN  18.0   Single        Virginia  Platinum
# 2     1/1/2019  151204    Male  27.0   Single     Connecticut     Basic
# 3     1/3/2019  151205    Male  71.0   Single          Hawaii     Basic
# 4     1/3/2019  151206  Female  34.0  Married      New Mexico  Platinum
# ...        ...     ...     ...   ...      ...             ...       ...
# 2505  5/1/2021  153695  Female  57.0   Single  South Carolina  Platinum
# 2506  5/1/2021  153696  Female  36.0  Married          Hawaii    Silver
# 2507  5/1/2021  153697    Male  22.0   Single  South Carolina     Basic
# 2508  5/1/2021  153698     NaN  44.0   Single        New York     Basic
# 2509  5/1/2021  153699    Male  48.0   Single      California    Silver
#
#       self-employed    Card    0   544.04
# 0           workers  PayPal  1.0  1572.60
# ...

# %% [markdown]
# # 3.4 Handling missing values

# %% [markdown]
# Handling missing values in the common task in the data pre-processing part.

# %% [markdown]
# # Display missing values information

# %%
df.isna().sum().sort_values(ascending=False)
# Out:
# 544.04           241
# 0                155
# 49                42
# Male              28
# self-employed     26
# 1/1/2019           0
# 151201             0
# Single             0
# Illinois           0
# Basic              0
# Card               0
# dtype: int64

# %%
df_new.drop(columns=['Amount_spent'], inplace=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[46], line 1
# ----> 1 df_new.drop(columns=['Amount_spent'], inplace=True)
#
# NameError: name 'df_new' is not defined
